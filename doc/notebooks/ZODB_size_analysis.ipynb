# %% [markdown]
# # ZODB Size Analysis

# %% [markdown]
# Maybe your Zope Object Data Base has an unexpected size. This notebook helps to find the big data objects in your ZODB. The code works with Zope2-generated ZODBs under Python2. To use it, please create a virtual environment first and place this notebook into a folder like described here:
#
# ```
#   506  virtualenv --python=python2 /home/jupyter
#   507  cd /home/jupyter/bin/
#   508  ./pip install pandas
#   509  ./pip install ZODB
#   510  ./pip install contextlib2
#   512  ./pip install jupyter
#   513  mkdir /home/jupyter/notebook
#   514  cd /home/jupyter/notebooks/
#   515  /home/jupyter/bin/jupyter notebook
# ```

# %%
from ZODB.DB import DB
import ZODB.FileStorage
import ZODB.POSException
from contextlib import contextmanager
import sys
import pandas as pd

# %%
def get_classname(obj):
    return obj.__class__.__module__ + '.' + obj.__class__.__name__

def get_title(o):
    try:
        return getattr(o, 'title', '')
    except:
        return ''

@contextmanager
def open_zodb(zodb_path):
    storage = ZODB.FileStorage.FileStorage(zodb_path)
    db = DB(storage)
    connection = db.open()
    try:
        yield storage, db, connection
    finally:
        connection.close()
        db.close()
        storage.close()    
    

def iter_objects(storage, db, connection):
    next_ = None
    while True:
        oid, tid, data, next_ = storage.record_iternext(next_)
        if next_ is None:
            break
        yield {
            'oid': oid,
            'tid': tid,
            'data': data,
            'obj': connection.get(oid)
        }

# %%
with open_zodb('Data.fs') as db:
    items = [
        [get_classname(o['obj']), len(o['data']), get_title(o['obj'])]
        for o in iter_objects(*db)
    ]
df = pd.DataFrame(items, columns=['classname', 'size', 'title'])

# %%
df.groupby(df['classname'])['size'].agg(['sum', 'count']).sort_values('sum', ascending=False)
# Out:
#                                                        sum  count
# classname
# Products.zms.zmscustom.ZMSCustom                    903928    166
# Products.PageTemplates.ZopePageTemplate.ZopePag...  354299     77
# BTrees.IOBTree.IOBTree                              316216     36
# Products.zms._zmsattributecontainer.ZMSAttribut...  285814    177
# OFS.Image.File                                      267504     36
# Products.PythonScripts.PythonScript.PythonScript    240665     74
# OFS.Image.Pdata                                     208820      2
# BTrees.IIBTree.IIBTree                               67298    316
# BTrees.IOBTree.IOBucket                              56592     46
# Products.zms.zms.ZMS                                 50705      2
# Products.zms.ZMSMetamodelProvider.ZMSMetamodelP...   36764      2
# OFS.Image.Image                                      31143      9
# Products.zms.zmslinkelement.ZMSLinkElement           21642      4
# BTrees.IIBTree.IITreeSet                             16900    358
# BTrees.OOBTree.OOBucket                              16202     18
# BTrees.OIBTree.OIBucket                              12468     12
# OFS.DTMLMethod.DTMLMethod                             6707      5
# OFS.Folder.Folder                                     6028     14
# Products.zms.ZMSFormatProvider.ZMSFormatProvider      5425      2
# Products.zms.ZMSWorkflowProvider.ZMSWorkflowPro...    5084      3
# Products.ZCTextIndex.OkapiIndex.OkapiIndex            3880     10
# BTrees.OIBTree.OIBTree                                2858      6
# Products.ZCTextIndex.ZCTextIndex.ZCTextIndex          2764     10
# Products.ZCatalog.Catalog.Catalog                     2202      4
# Products.PluginIndexes.FieldIndex.FieldIndex.Fi...    2028      6
# OFS.Application.Application                           1952      1
# BTrees.OOBTree.OOBTree                                1720      6
# Products.ExternalMethod.ExternalMethod.External...    1642      2
# Products.ZCatalog.ZCatalog.ZCatalog                   1594      4
# BTrees.Length.Length                                  1214     42
# Products.ZCTextIndex.ZCTextIndex.PLexicon             1040      2
# Products.zms.ZMSZCatalogAdapter.ZMSZCatalogAdapter     944      2
# Products.zms.ZMSMetacmdProvider.ZMSMetacmdProvider     942      2
# Products.Sessions.BrowserIdManager.BrowserIdMan...     326      1
# Products.zms.zmstrashcan.ZMSTrashcan                   292      2
# Products.Sessions.SessionDataManager.SessionDat...     234      1
# Products.zms.zmslog.ZMSLog                             232      2
# Products.zms.ZMSZCatalogConnector.ZMSZCatalogCo...     184      2
# Products.Sessions.SessionDataManager.SessionDat...     156      1
# Products.zms._sequence.Sequence                        150      2
# Products.zms.ZMSWorkflowProviderAcquired.ZMSWor...     143      1
# Products.ZODBMountPoint.MountedObject.MountedOb...     136      1
# AccessControl.users.User                               133      1
# OFS.userfolder.UserFolder                              121      1
# persistent.mapping.PersistentMapping                   119      1
# Persistence.mapping.PersistentMapping                  111      1
# App.ApplicationManager.ApplicationManager              107      1
# Products.SiteAccess.VirtualHostMonster.VirtualH...      92      1
# Products.SiteErrorLog.SiteErrorLog.SiteErrorLog         56      1
# App.Product.ProductFolder                               34      1

# %%
df[df['classname']=="Products.zms.zmscustom.ZMSCustom"].sort_values('size').tail(30)
# Out:
#                              classname  size title
# 246   Products.zms.zmscustom.ZMSCustom  5483
# 45    Products.zms.zmscustom.ZMSCustom  5483
# 88    Products.zms.zmscustom.ZMSCustom  5483
# 888   Products.zms.zmscustom.ZMSCustom  5497
# 902   Products.zms.zmscustom.ZMSCustom  5498
# 911   Products.zms.zmscustom.ZMSCustom  5498
# 795   Products.zms.zmscustom.ZMSCustom  5498
# 52    Products.zms.zmscustom.ZMSCustom  5501
# 110   Products.zms.zmscustom.ZMSCustom  5501
# 164   Products.zms.zmscustom.ZMSCustom  5505
# 898   Products.zms.zmscustom.ZMSCustom  5516
# 990   Products.zms.zmscustom.ZMSCustom  5516
# 939   Products.zms.zmscustom.ZMSCustom  5520
# 161   Products.zms.zmscustom.ZMSCustom  5540
# 170   Products.zms.zmscustom.ZMSCustom  5548
# 775   Products.zms.zmscustom.ZMSCustom  5553
# 876   Products.zms.zmscustom.ZMSCustom  5560
# 1027  Products.zms.zmscustom.ZMSCustom  5563
# 27    Products.zms.zmscustom.ZMSCustom  5618
# 41    Products.zms.zmscustom.ZMSCustom  5619
# 50    Products.zms.zmscustom.ZMSCustom  5637
# 766   Products.zms.zmscustom.ZMSCustom  5648
# 784   Products.zms.zmscustom.ZMSCustom  5649
# 40    Products.zms.zmscustom.ZMSCustom  5665
# 38    Products.zms.zmscustom.ZMSCustom  5665
# 907   Products.zms.zmscustom.ZMSCustom  5667
# 781   Products.zms.zmscustom.ZMSCustom  5700
# 783   Products.zms.zmscustom.ZMSCustom  5700
# 42    Products.zms.zmscustom.ZMSCustom  5711
# 785   Products.zms.zmscustom.ZMSCustom  5751

# %%
df['size'].sum()
# Out:
# 2937610

# %%
df['size'].count()
# Out:
# 1477

# %%
df['size'].median()
# Out:
# 255.0
